# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.
#
# Then, put train data zip file in the yolov5 folder.
#
# Put the custom_data.yaml file under data directory.
#
# Put in the relevant pt file under yolov5

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks\
# Out:
# YOLOv5 🚀 v7.0-43-gf72f0fe Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (A100-SXM4-40GB, 40536MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 23.0/166.8 GB disk)

# %%
# !mv train_data.zip ../train_data.zip
# !unzip -q ../train_data.zip -d ../

# %%
# Train YOLOv5s on COCO128 for 125 epochs
# !python train.py --img 640 --batch 16 --epochs 125 --data custom_data.yaml --weights yolov5m.pt --cfg models/yolov5m.yaml --cache
# Out:
# train: weights=yolov5m.pt, cfg=models/yolov5m.yaml, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=125, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-43-gf72f0fe Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (A100-SXM4-40GB, 40536MiB)
#
# ...

# %%
# !zip -r runs.zip ./runs/train/exp2
# Out:
#   adding: runs/train/exp2/ (stored 0%)
#   adding: runs/train/exp2/train_batch2.jpg (deflated 3%)
#   adding: runs/train/exp2/results.png (deflated 8%)
#   adding: runs/train/exp2/R_curve.png (deflated 13%)
#   adding: runs/train/exp2/results.csv (deflated 83%)
#   adding: runs/train/exp2/events.out.tfevents.1671561807.d672b0ef8cc8.18350.0 (deflated 50%)
#   adding: runs/train/exp2/val_batch1_labels.jpg (deflated 6%)
#   adding: runs/train/exp2/hyp.yaml (deflated 45%)
#   adding: runs/train/exp2/F1_curve.png (deflated 13%)
#   adding: runs/train/exp2/val_batch1_pred.jpg (deflated 6%)
#   adding: runs/train/exp2/val_batch0_pred.jpg (deflated 3%)
#   adding: runs/train/exp2/weights/ (stored 0%)
#   adding: runs/train/exp2/weights/best.pt (deflated 9%)
#   adding: runs/train/exp2/weights/last.pt (deflated 9%)
#   adding: runs/train/exp2/confusion_matrix.png (deflated 36%)
#   adding: runs/train/exp2/train_batch1.jpg (deflated 3%)
#   adding: runs/train/exp2/P_curve.png (deflated 12%)
# ...
